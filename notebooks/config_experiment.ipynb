# %%
from dataclasses import dataclass
from typing import Any
@dataclass
class config:
    r = 1
    def __getattribute__(self, name: str) -> Any:
        return self

# %%
c = config()
c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /mnt/work/SAIR/airqo_pipeline/.venv/lib/python3.13/site-packages/IPython/core/formatters.py:975, in IPythonDisplayFormatter.__call__(self, obj)
#     972 if self.enabled:
#     973     # lookup registered printer
#     974     try:
# --> 975         printer = self.lookup(obj)
#     976     except KeyError:
#     977         pass
#
# File /mnt/work/SAIR/airqo_pipeline/.venv/lib/python3.13/site-packages/IPython/core/formatters.py:456, in BaseFormatter.lookup(self, obj)
#     454     return self.singleton_printers[obj_id]
#     455 # then lookup by type
# --> 456 return self.lookup_by_type(_get_type(obj))
#
# File /mnt/work/SAIR/airqo_pipeline/.venv/lib/python3.13/site-packages/IPython/core/formatters.py:485, in BaseFormatter.lookup_by_type(self, typ)
#     483         return self.deferred_printers[typ_key]
#     484 else:
# ...

# %%
c.r
# Out:
# 1
